# %% [markdown]
# <a href="https://colab.research.google.com/github/neysin/code-traing/blob/main/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EC%8A%A4_%EC%BD%94%ED%85%8C_%ED%95%B4%EC%89%AC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 해쉬 - level 1 \
# 완주하지 못한 선수

# %%
# 요구사항은 만족하나 데이터가 많아질수록 효율성에서 통과가 안됨
def solution(participant, completion):
    for i in participant:
        if i in completion:
            completion.remove(i)
        else:
            return i

participant = ["mislav", "stanko", "mislav", "ana"]
completion = ["stanko", "ana", "mislav"]
solution(participant, completion)
# Out:
# 'mislav'

# %%
# 참가자와 완주자 리스트를 정렬 후 같은 위치에 존재하지 않는 참가자나 완주하지 못한 참가자를 반환
# nlogn 의 시간 복잡도를 가지고 있어 효율성 테스트에서 통과
def solution(participant, completion):
    participant.sort()
    completion.sort()
    for i in range(len(completion)):
        if(participant[i] != completion[i]):
            return participant[i]
    return participant[-1]

participant = ["mislav", "stanko", "mislav", "ana"]
completion = ["stanko", "ana", "mislav"]
solution(participant, completion)
# Out:
# 'mislav'

# %%
# 해쉬 테이블을 사용하여 요구사항 구현
# answer을 딕셔너리 형태로 구현 후 참가자를 하나씩 넣어줌. value에는 1값을 넣어주고 중복되는 이름의 참가자가 존재 시 1씩 늘어나는 구조
# answer에서 완주자의 이름을 참조하여 존재 시 value를 1씩 빼주어 결과적으로 value가 0만 남는 참가자가 완주자임을 의미
def solution(participant, completion):
    answer = {}
    for i in participant:
        answer[i] = answer.get(i, 0) + 1
    for j in completion:
        answer[j] -= 1
    for k in answer:
        if answer[k]:
            return k


participant = ["mislav", "stanko", "mislav", "ana"]
completion = ["stanko", "ana", "mislav"]
solution(participant, completion)
# Out:
# 'mislav'
